# %% [markdown]
# # Environment Verification
#
# This notebook verifies that the local development environment is correctly configured for Data Science workflows.

# %%
# !python --version

# %%
# !conda --version

# %%
# !jupyter --version

# %%
print("Python code executing successfully inside Jupyter! Environment is ready.")
