# %% [markdown]
# # Understanding Code and Markdown Cells in Jupyter Notebook

# %% [markdown]
# ## Purpose
#
# This notebook demonstrates the correct use of Code and Markdown cells.
#
# - Code cells execute Python code
# - Markdown cells explain the code

# %% [markdown]
# ## Example 1
#
# This code will add two numbers.

# %%
a = 10
b = 20
print("Sum:", a + b)
# Out:
# Sum: 30

# %% [markdown]
# The above code adds two numbers and prints the result.

# %% [markdown]
# ## Example 2
#
# This code will print a greeting.

# %%
name = "Hasan"
print("Hello", name)
# Out:
# Hello Hasan

# %% [markdown]
# ## Conclusion
#
# - Code cells are used for execution
# - Markdown cells are used for explanation
